# %% [markdown]
# Sidhdi Vijay K 22MIC0168

# %%
# !pip install jieba
# Out:
# ...
#      ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#      --------------------------------------- 0.0/19.2 MB 217.9 kB/s eta 0:01:29
#      --------------------------------------- 0.0/19.2 MB 187.9 kB/s eta 0:01:43
#      --------------------------------------- 0.1/19.2 MB 290.5 kB/s eta 0:01:06
#      --------------------------------------- 0.1/19.2 MB 435.7 kB/s eta 0:00:44
#      --------------------------------------- 0.2/19.2 MB 743.9 kB/s eta 0:00:26
#      --------------------------------------- 0.2/19.2 MB 778.2 kB/s eta 0:00:25
#       -------------------------------------- 0.3/19.2 MB 981.5 kB/s eta 0:00:20
#      - -------------------------------------- 0.5/19.2 MB 1.3 MB/s eta 0:00:14
#      - -------------------------------------- 0.6/19.2 MB 1.4 MB/s eta 0:00:14
#      - -------------------------------------- 0.8/19.2 MB 1.7 MB/s eta 0:00:11
# ...

# %%
with open(r"C:\Users\Span220\Desktop\a.txt", "r", encoding="utf8") as text:
    data = text.read()

# %%
data
# Out:
# '我们能在周二前看到你演讲的全文吗？'

# %%
import jieba
seg_list = jieba.cut(data, cut_all=False)  # precise mode
print("/ ".join(seg_list))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\Span220\AppData\Local\Temp\jieba.cache
# Loading model cost 1.055 seconds.
# Prefix dict has been built successfully.
# 我们/ 能/ 在/ 周二/ 前/ 看到/ 你/ 演讲/ 的/ 全文/ 吗/ ？
