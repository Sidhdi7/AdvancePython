# %%
# prove string is immutable by printing its id() and why you should not put in loop and how string is better, 100 factorial,encoding equalent of keyboard charecter, extract character from gutenberg novel and encode4 it in utf-8

# %%
import unicodedata
s=unicodedata.lookup('GRINNING FACE')
print(s)
# Out:
# 😀

# %%
print('😀 is a simley')
# Out:
# 😀 is a simley

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
def func(name):
    
    x=ord(name)
    return hex(x)

# %%
func('a')
# Out:
# '0x61'

# %%
import nltk
texts='Python is a high-level, interpreted, general-purpose programming language. It was created by Guido van Rossum and first released in 1991. Python is known for its clear and readable syntax, which emphasizes code readability and allows developers to write programs with fewer lines of code compared to some other languages.' 

for text in texts:
    sentences=nltk.sent_tokenize(text)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged_words=nltk.pos_tag(words)
        print(tagged_words)
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [('P', 'NN')]
# [('y', 'NN')]
# [('t', 'NN')]
# [('h', 'NN')]
# [('o', 'NN')]
# [('n', 'NN')]
# [('i', 'NN')]
# [('s', 'NN')]
# [('a', 'DT')]
# [('h', 'NN')]
# [('i', 'NN')]
# [('g', 'NN')]
# [('h', 'NN')]
# [('-', ':')]
# [('l', 'NN')]
# [('e', 'NN')]
# [('v', 'NN')]
# [('e', 'NN')]
# [('l', 'NN')]
# [(',', ',')]
# [('i', 'NN')]
# [('n', 'NN')]
# [('t', 'NN')]
# [('e', 'NN')]
# [('r', 'NN')]
# [('p', 'NN')]
# [('r', 'NN')]
# [('e', 'NN')]
# [('t', 'NN')]
# [('e', 'NN')]
# [('d', 'NN')]
# [(',', ',')]
# [('g', 'NN')]
# [('e', 'NN')]
# [('n', 'NN')]
# [('e', 'NN')]
# [('r', 'NN')]
# [('a', 'DT')]
# [('l', 'NN')]
# [('-', ':')]
# [('p', 'NN')]
# [('u', 'NN')]
# [('r', 'NN')]
# [('p', 'NN')]
# [('o', 'NN')]
# [('s', 'NN')]
# [('e', 'NN')]
# ...
